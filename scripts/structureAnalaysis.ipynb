# %%
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("soft_pf0.1_sp100_lp100_reduced10_reduced1.density",delim_whitespace=True,header=None)
#df=pd.read_csv("soft_pf0.1_sp050_lp100_condensed.density",delim_whitespace=True,header=None)

# %%
#df=pd.read_csv("soft_pf0.1_sp050_lp100_condensed.density",delim_whitespace=True,header=None)
fig,ax = plt.subplots(1,2,figsize=(8,3))
#sns.heatmap(df,cmap=cm.viridis,ax=ax[0])
data = df.replace(0,1e-10)
data=data/data.sum().sum()
min_data = data.min().min()
if (min_data == 0):
    min_data = 1
max_data = data.max().max()
log_norm = LogNorm(vmin=min_data, vmax=max_data)
cbar_ticks = [10**i for i in 
              range(int(np.floor(np.log10(min_data))),
                    1 + int(np.ceil(np.log10(max_data))))]
sns.heatmap(data, norm=log_norm,
            cmap=cm.viridis, ax=ax[0],
            cbar_kws={"ticks": cbar_ticks})
fft_data=np.fft.fftshift(np.fft.fft2(df))
data = np.abs(fft_data)
data=data/data.sum().sum()
min_data = data.min().min()
if (min_data == 0):
    min_data = 1
max_data = data.max().max()
log_norm = LogNorm(vmin=min_data, vmax=max_data)
cbar_ticks = [10**i for i in 
              range(int(np.floor(np.log10(min_data))),
                    1 + int(np.ceil(np.log10(max_data))))]
sns.heatmap(data, norm=log_norm,
            cmap=cm.viridis, ax=ax[1],
            cbar_kws={"ticks": cbar_ticks})
fig.savefig("test.png",dpi=300)

# %%
fig.savefig("test.png",dpi=300)

# %%
fft_data=np.fft.fftshift(np.fft.fft2(df))
data = np.abs(fft_data)
plt.figure()
plt.plot(data[data.shape[0]//2])
plt.xlim(4975,5025)
plt.show()

# %%
df=pd.read_csv("sp100_lp100_fft.txt",header=None)
df.columns=["data"]
df.data = df.data.apply(lambda x: x**2)

# %%
plt.figure()
df.plot(y='data')
plt.xlim(4975,5025)
plt.show()

# %%
fig,ax=plt.subplots(1,1)
n=0.01
labels=[]
for i,sp in enumerate(['015','025','050','100']):
    for j,lp in enumerate(['020','050','100']):
        if sp=='025' and lp=='050':
            continue
        if sp=='050' and lp=='100':
            sp='060'
        if sp=='025' and lp=='100':
            sp='030'
        label='sp'+sp+'_lp'+lp
        fname = label+'_fft.txt'
        df=pd.read_csv(fname,header=None)
        df.columns=['data']
        df.data = df.data**2
        df.plot(ax=ax)
        labels.append(label)
        #f = open(fname,'r')
        #nums[i][j] = float(f.readline())
        #f.close()
ax.legend(labels)
ax.set_xlim(5000-n,5000+n)
ax.set_ylim(170,190)
# Out:
# (170, 190)

# %%
nums
# Out:
# array([[13.2624296 , 13.31539209, 13.4165334 ],
#        [13.24627185,  0.        , 13.54656982],
#        [13.25441787, 13.60443475,  0.        ],
#        [13.25436988, 13.35145461, 13.41455263]])

# %%
df.head()
# Out:
#            0             1             2             3             4     \
# 0  6.290640e-08  8.006270e-08  6.862520e-08  4.003130e-08  7.434390e-08
# 1  6.290640e-08  6.290640e-08  6.862520e-08  5.146890e-08  7.434390e-08
# 2  6.290640e-08  6.290640e-08  6.290640e-08  6.290640e-08  9.721900e-08
# 3  2.859380e-08  3.431260e-08  9.721900e-08  6.290640e-08  6.290640e-08
# 4  3.431260e-08  2.859380e-08  9.721900e-08  9.721900e-08  5.146890e-08
#
#            5             6             7             8             9     \
# 0  9.150020e-08  7.434390e-08  3.431260e-08  6.290640e-08  8.006270e-08
# 1  7.434390e-08  6.290640e-08  4.575010e-08  7.434390e-08  1.029380e-07
# 2  7.434390e-08  4.575010e-08  7.434390e-08  9.150020e-08  5.146890e-08
# 3  8.006270e-08  6.862520e-08  6.862520e-08  7.434390e-08  4.003130e-08
# 4  6.290640e-08  5.718760e-08  6.290640e-08  6.290640e-08  5.146890e-08
#
#        ...               9990          9991          9992          9993  \
# 0      ...       4.575010e-08  8.006270e-08  4.575010e-08  6.862520e-08
# 1      ...       6.290640e-08  1.029380e-07  4.003130e-08  5.146890e-08
# 2      ...       5.718760e-08  8.578150e-08  4.003130e-08  7.434390e-08
# 3      ...       8.006270e-08  8.006270e-08  4.575010e-08  9.150020e-08
# 4      ...       8.006270e-08  7.434390e-08  5.718760e-08  8.006270e-08
#
#            9994          9995          9996          9997          9998  \
# 0  6.290640e-08  3.431260e-08  4.003130e-08  6.290640e-08  5.146890e-08
# 1  5.718760e-08  2.287510e-08  5.146890e-08  6.862520e-08  6.290640e-08
# 2  5.146890e-08  6.290640e-08  4.575010e-08  5.146890e-08  4.575010e-08
# 3  6.290640e-08  5.146890e-08  4.575010e-08  4.575010e-08  5.146890e-08
# 4  4.575010e-08  2.859380e-08  2.859380e-08  4.003130e-08  2.287510e-08
#
#            9999
# 0  8.006270e-08
# 1  6.862520e-08
# 2  5.146890e-08
# 3  8.578150e-08
# 4  9.150020e-08
#
# [5 rows x 10000 columns]

# %%
plt.pcolor(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-5c1d28f7ab4c> in <module>()
# ----> 1 plt.pcolor(df)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/pyplot.py in pcolor(*args, **kwargs)
#    3266                       mplDeprecation)
#    3267     try:
# -> 3268         ret = ax.pcolor(*args, **kwargs)
#    3269     finally:
#    3270         ax._hold = washold
#
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pcolor(self, *args, **kwargs)
#    5794         kwargs.setdefault('snap', False)
#    5795
# -> 5796         collection = mcoll.PolyCollection(verts, **kwargs)
#    5797
#    5798         collection.set_alpha(alpha)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, verts, sizes, closed, **kwargs)
#     961         Collection.__init__(self, **kwargs)
#     962         self.set_sizes(sizes)
# --> 963         self.set_verts(verts, closed)
#     964         self.stale = True
#     965
#
# /usr/local/lib/python3.7/site-packages/matplotlib/collections.py in set_verts(self, verts, closed)
#     982                     codes[0] = mpath.Path.MOVETO
#     983                     codes[-1] = mpath.Path.CLOSEPOLY
# --> 984                     self._paths.append(mpath.Path(xy, codes))
#     985                 else:
#     986                     self._paths.append(mpath.Path(xy))
#
# /usr/local/lib/python3.7/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     152         self._codes = codes
#     153         self._interpolation_steps = _interpolation_steps
# --> 154         self._update_values()
#     155
#     156         if readonly:
#
# /usr/local/lib/python3.7/site-packages/matplotlib/path.py in _update_values(self)
#     197
#     198     def _update_values(self):
# --> 199         self._simplify_threshold = rcParams['path.simplify_threshold']
#     200         self._should_simplify = (
#     201             self._simplify_threshold > 0 and
#
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py in __getitem__(self, key)
#     929                 'list of valid parameters.' % (key,))
#     930
# --> 931     def __getitem__(self, key):
#     932         inverse_alt = None
#     933         if key in _deprecated_map:
#
# KeyboardInterrupt:

# %%
#df=pd.read_csv("soft_pf0.1_sp100_lp100_reduced10_reduced1.structure",
#               header=None,delim_whitespace=True)
df=pd.read_csv("soft_pf0.1_sp050_lp100_reduced10_reduced1.structure",
               header=None,delim_whitespace=True)

# %%
#df.columns=['k_x','k_y','data']

# %%
#df=df.pivot(index='k_x',columns='k_y',values='data')

# %%
#data=df.replace(0,1e-9)
data=df
min_data = data.min().min()
#if (min_data == 0):
#    min_data = 1e-9
max_data = data.max().max()
log_norm = LogNorm(vmin=min_data, vmax=max_data)
cbar_ticks = [10**i for i in 
              range(int(np.floor(np.log10(min_data))),
                    1 + int(np.ceil(np.log10(max_data))))]
sns.heatmap(np.fft.fftshift(data), norm=log_norm,
            cmap=cm.viridis,
            cbar_kws={"ticks": cbar_ticks})

# %%
data_shift=np.fft.fftshift(data)
data_1d = data_shift[data_shift.shape[0]//2]

# %%
n=50
plt.figure()
plt.plot(data_1d)
plt.xlim(500-n,500+n)
plt.show()

# %%
k=4-5j

# %%
np.abs(k)
# Out:
# 6.4031242374328485

# %%
np.sqrt(16-25)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.
# nan

# %%
df.shape
# Out:
# (1000, 1000)
